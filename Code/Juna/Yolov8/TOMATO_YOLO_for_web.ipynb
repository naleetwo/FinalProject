# %%
from ultralytics import YOLO
import numpy as np
from PIL import Image
import requests
from io import BytesIO
import cv2

# %%
import tensorflow as tf

# %%
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from tqdm import tqdm
import os
import json

import matplotlib as mlp
import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname = "C:/Windows/Fonts/malgun.ttf").get_name()
plt.rc("font", family = font_name)
mlp.rcParams["axes.unicode_minus"] = False

# %%
import numpy as np

# %%
from ultralytics import YOLO

# %%
# model = YOLO("data/tomato_yolo_shuffle/best(shuffle_Epochs100).pt")

# %%
model = YOLO("data/tomato_yolo_shuffle_2/best(7classes_100).pt")

# %%
result = model.predict(source="C:/juna27/PythonWork/AI/data/tomato_yolo_shuffle_2/test_test",
                       save=True, save_txt=True)

# show=True,
# Out:
# image 1/2 C:\juna27\PythonWork\AI\data\tomato_yolo_shuffle_2\test_test\V006_77_1_18_11_03_13_2_7688w_20201006_58.jpg: 320x416 1 Leaf Mold Mid, 55.9ms
# image 2/2 C:\juna27\PythonWork\AI\data\tomato_yolo_shuffle_2\test_test\V006_77_1_19_11_03_12_2_2588q_20201112_1_a0006.jpeg: 416x320 1 TYLCV Mid, 38.9ms
# Speed: 1.5ms preprocess, 47.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 416)
# Results saved to runs\detect\predict5
# 2 labels saved to runs\detect\predict5\labels

# %%
import matplotlib as plt

# %%
len(result)
# Out:
# 2

# %%
result
# Out:
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Healthy', 1: 'Leaf Mold Early', 2: 'Leaf Mold Mid', 3: 'Leaf Mold Late', 4: 'TYLCV Early', 5: 'TYLCV Mid', 6: 'TYLCV Late'}
#  orig_img: array([[[121, 153, 112],
#          [114, 148, 107],
#          [107, 145, 103],
#          ...,
#          [ 69,  78,  65],
#          [ 80,  86,  75],
#          [ 77,  83,  72]],
#
#         [[112, 148, 106],
#          [112, 150, 108],
#          [ 99, 142,  99],
#          ...,
#          [ 70,  79,  66],
#          [ 73,  79,  68],
#          [ 79,  85,  74]],
#
#         [[100, 145, 102],
#          [ 97, 143, 100],
#          [ 87, 136,  92],
#          ...,
#          [ 71,  80,  67],
#          [ 68,  75,  62],
#          [ 77,  84,  71]],
#
#         ...,
#
#         [[ 91, 191, 173],
#          [ 85, 186, 165],
#          [ 80, 184, 161],
# ...

# %%
result[0]
# Out:
# ultralytics.yolo.engine.results.Results object with attributes:
#
# boxes: ultralytics.yolo.engine.results.Boxes object
# keypoints: None
# keys: ['boxes']
# masks: None
# names: {0: 'Healthy', 1: 'Leaf Mold Early', 2: 'Leaf Mold Mid', 3: 'Leaf Mold Late', 4: 'TYLCV Early', 5: 'TYLCV Mid', 6: 'TYLCV Late'}
# orig_img: array([[[121, 153, 112],
#         [114, 148, 107],
#         [107, 145, 103],
#         ...,
#         [ 69,  78,  65],
#         [ 80,  86,  75],
#         [ 77,  83,  72]],
#
#        [[112, 148, 106],
#         [112, 150, 108],
#         [ 99, 142,  99],
#         ...,
#         [ 70,  79,  66],
#         [ 73,  79,  68],
#         [ 79,  85,  74]],
#
#        [[100, 145, 102],
#         [ 97, 143, 100],
#         [ 87, 136,  92],
#         ...,
#         [ 71,  80,  67],
#         [ 68,  75,  62],
#         [ 77,  84,  71]],
#
#        ...,
#
#        [[ 91, 191, 173],
#         [ 85, 186, 165],
#         [ 80, 184, 161],
#         ...,
#         [112,  87,  91],
# ...

# %%
result[0].boxes
# Out:
# WARNING  'Boxes.boxes' is deprecated. Use 'Boxes.data' instead.
# ultralytics.yolo.engine.results.Boxes object with attributes:
#
# boxes: tensor([[184.2692, 246.7993, 807.6489, 653.6929,   0.9301,   2.0000]])
# cls: tensor([2.])
# conf: tensor([0.9301])
# data: tensor([[184.2692, 246.7993, 807.6489, 653.6929,   0.9301,   2.0000]])
# id: None
# is_track: False
# orig_shape: (756, 1008)
# shape: torch.Size([1, 6])
# xywh: tensor([[495.9590, 450.2461, 623.3798, 406.8937]])
# xywhn: tensor([[0.4920, 0.5956, 0.6184, 0.5382]])
# xyxy: tensor([[184.2692, 246.7993, 807.6489, 653.6929]])
# xyxyn: tensor([[0.1828, 0.3265, 0.8012, 0.8647]])

# %%
result[0].names.get(1)
# Out:
# 'Leaf Mold Early'

# %%
# h, w
result[0].orig_shape
# Out:
# (756, 1008)

# %%
result[0].boxes.conf
# Out:
# tensor([0.9301])

# %%
result[0].boxes.xywhn
# Out:
# tensor([[0.4920, 0.5956, 0.6184, 0.5382]])

# %%
result[0].boxes.cls.numpy().tolist()[0]
# Out:
# 2.0

# %%
result[0].names.get(result[0].boxes.cls.numpy().tolist()[0])
# Out:
# 'Leaf Mold Mid'

# %%
coor = result[0].boxes.xywhn.numpy().tolist()[0]
coor
# Out:
# [0.49202287197113037,
#  0.5955635905265808,
#  0.6184322834014893,
#  0.538219153881073]

# %%
result[0].orig_img
# Out:
# array([[[121, 153, 112],
#         [114, 148, 107],
#         [107, 145, 103],
#         ...,
#         [ 69,  78,  65],
#         [ 80,  86,  75],
#         [ 77,  83,  72]],
#
#        [[112, 148, 106],
#         [112, 150, 108],
#         [ 99, 142,  99],
#         ...,
#         [ 70,  79,  66],
#         [ 73,  79,  68],
#         [ 79,  85,  74]],
#
#        [[100, 145, 102],
#         [ 97, 143, 100],
#         [ 87, 136,  92],
#         ...,
#         [ 71,  80,  67],
#         [ 68,  75,  62],
#         [ 77,  84,  71]],
#
#        ...,
#
#        [[ 91, 191, 173],
#         [ 85, 186, 165],
#         [ 80, 184, 161],
#         ...,
#         [112,  87,  91],
#         [ 94,  69,  73],
#         [110,  85,  89]],
#
#        [[ 95, 195, 177],
#         [ 88, 189, 168],
#         [ 83, 187, 164],
#         ...,
#         [102,  77,  81],
#         [ 96,  71,  75],
#         [ 90,  65,  69]],
#
#        [[101, 201, 183],
#         [ 94, 195, 174],
#         [ 87, 191, 168],
# ...

# %%
from PIL import Image

# %%
# 주어진 데이터를 NumPy 배열로 변환합니다.
# data = np.array(result[0].orig_img, dtype=np.uint8)

# 이미지를 표시합니다.
# plt.imshow(data)
# plt.axis('off')  # 축을 표시하지 않도록 설정합니다.
# plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 주어진 데이터를 NumPy 배열로 변환합니다.
data = np.array(result[0].orig_img, dtype=np.uint8)

# 이미지를 표시합니다.
plt.imshow(data)

# YOLO 형식의 좌표를 사용하여 박스를 그립니다.
box_center_x = coor[0]
box_center_y = coor[1]
box_width = coor[2]
box_height = coor[3]

# 좌표 변환
image_height, image_width, _ = data.shape
x = (box_center_x - box_width / 2) * image_width
y = (box_center_y - box_height / 2) * image_height
w = box_width * image_width
h = box_height * image_height

# 박스를 그립니다.
rect = plt.Rectangle((x, y), w, h, linewidth=5, edgecolor='g', facecolor='none')
plt.gca().add_patch(rect)

plt.axis('off')  # 축을 표시하지 않도록 설정합니다.
plt.title(result[0].names.get(result[0].boxes.cls.numpy().tolist()[0]))
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 주어진 데이터를 NumPy 배열로 변환합니다.
data = np.array(result[0].orig_img, dtype=np.uint8)

# 이미지를 표시합니다.
plt.imshow(data)

# YOLO 형식의 좌표를 사용하여 박스를 그립니다.
box_center_x = coor[0]
box_center_y = coor[1]
box_width = coor[2]
box_height = coor[3]

# 좌표 변환
image_height, image_width, _ = data.shape
x = (box_center_x - box_width / 2) * image_width
y = (box_center_y - box_height / 2) * image_height
w = box_width * image_width
h = box_height * image_height

# 박스를 그립니다.
rect = plt.Rectangle((x, y), w, h, linewidth=5, edgecolor='r', facecolor='none')
plt.gca().add_patch(rect)

# 사각형 위에 텍스트를 추가합니다.
plt.text(image_width / 2, image_height / 2, 
         "zzz", fontsize=16, color='r')

# 이미지를 표시합니다.
plt.axis("off")
plt.show()

# %%
# from PIL import Image
# import matplotlib.pyplot as plt
# import numpy as np

# # 주어진 데이터를 NumPy 배열로 변환합니다.
# data = np.array([[[121, 153, 112],
#                  [114, 148, 107],
#                  [107, 145, 103],
#                  # ... 중략 ...
#                  [ 87,  62,  66],
#                  [ 90,  65,  69]]], dtype=np.uint8)

# # NumPy 배열을 PIL 이미지로 변환합니다.
# image = Image.fromarray(data)

# # 이미지를 표시합니다.
# plt.imshow(image)
# plt.axis('off')  # 축을 표시하지 않도록 설정합니다.
# plt.show()

# # 모델로 예측을 수행하고 결과를 출력합니다.
# # 이 부분은 예시 코드이며, 실제 모델에 맞게 예측을 수행해야 합니다.
# # model.predict(image)
# # 예측 결과를 출력합니다.
