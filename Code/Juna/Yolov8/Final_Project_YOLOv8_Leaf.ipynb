# %% [markdown]
# ## Leaf

# %%
from datetime import datetime

from PIL import Image
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from tqdm import tqdm
import os
import json
import pandas as pd


import matplotlib as mlp
import matplotlib.font_manager as fm
font_name = fm.FontProperties(fname = "C:/Windows/Fonts/malgun.ttf").get_name()
plt.rc("font", family = font_name)
mlp.rcParams["axes.unicode_minus"] = False

# %% [markdown]
# ## YOLOv8

# %% [markdown]
# C:\Users\acorn\AppData\Roaming\Ultralytics
#
#
#
# settings.yaml 확인

# %%
import ultralytics

# %%
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.117  Python-3.9.13 torch-2.0.1+cpu CPU
# Setup complete  (8 CPUs, 15.9 GB RAM, 527.3/915.8 GB disk)

# %% [markdown]
# ### yolov8
# - detection models
#     - n
#     - s
#     - m
#     - l
#     - x

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
# model = YOLO("yolov8s.pt")

# %% [markdown]
# ## best.pt

# %%
# model = YOLO("C:/juna27/PythonWork/AI/data/tomato_yolo/best_epochs6.pt")

# %%
# print(len(model.names))
# print("\n")
# print(model.names)

# %%
import yaml

data = {
    "train" : "train/images/",
    "val" : "val/images/",
    "test" : "test/images/",
    "nc" : 3,
    "names": ['healthy', 'Leaf mold', 'TYLCV']
}

with open("data/tomato_yolo/tom_out_leaf.yaml", "w") as f:
    yaml.dump(data, f)

# %%
start_time = datetime.now()
print("Start Training :", start_time)
##########


model.train(data="C:/juna27/PythonWork/AI/data/tomato_yolo/tom_out_leaf.yaml",
            epochs=8, patience=4,
            batch=32, imgsz=416)


##########
end_time = datetime.now()
print("End of Training :", end_time)
print("\nTime taken :", end_time-start_time)
# Out:
# Start Training : 2023-06-27 18:58:06.633668
# New https://pypi.org/project/ultralytics/8.0.123 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.117  Python-3.9.13 torch-2.0.1+cpu CPU
# ...

# %% [markdown]
# https://www.waytoliah.com/1491

# %% [markdown]
# ## runs/detect 경로는 ipynb 경로와 같음

# %%
results = model.predict(source="data/tomato_yolo/test/images/", save=True)
# Out:
# image 1/207 C:\juna27\PythonWork\AI\data\tomato_yolo\test\images\02a29ab9-8cba-47a0-bc2f-e7af7dbae149___Crnl_L.Mold 7165.JPG: 416x416 2 TYLCVs, 149.6ms
# image 2/207 C:\juna27\PythonWork\AI\data\tomato_yolo\test\images\0a555f63-bf03-4958-8993-e1932b8dce9f___Crnl_L.Mold 9064.JPG: 416x416 1 Leaf mold, 1 TYLCV, 43.9ms
# image 3/207 C:\juna27\PythonWork\AI\data\tomato_yolo\test\images\0a9b3ff4-5343-4814-ac2c-fdb3613d4e4d___Crnl_L.Mold 6559.JPG: 416x416 1 TYLCV, 37.9ms
# image 4/207 C:\juna27\PythonWork\AI\data\tomato_yolo\test\images\0ac36661-a47d-47ff-8948-42edec033b87___Crnl_L.Mold 9127.JPG: 416x416 1 TYLCV, 33.9ms
# image 5/207 C:\juna27\PythonWork\AI\data\tomato_yolo\test\images\0adab1d4-5696-4cd8-8453-3931b70e856d___Crnl_L.Mold 8689.JPG: 416x416 (no detections), 36.9ms
# image 6/207 C:\juna27\PythonWork\AI\data\tomato_yolo\test\images\0ae36892-5cb1-476e-8a51-b7fd8183a535___Crnl_L.Mold 6728.JPG: 416x416 (no detections), 42.9ms
# ...

# %% [markdown]
# C:\Users\acorn\AppData\Roaming\Ultralytics
#
#
#
# settings.yaml 확인

# %% [markdown]
# ### best 6 추론 해보기

# %%
# model_custom = YOLO("C:/juna27/PythonWork/AI/data/tomato_yolo/best_epochs6.pt")

# %%
# model_custom.predict(source="data/tomato_yolo/test/images/", save=True)
# Out:
# image 1/207 C:\juna27\PythonWork\AI\data\tomato_yolo\test\images\02a29ab9-8cba-47a0-bc2f-e7af7dbae149___Crnl_L.Mold 7165.JPG: 416x416 2 diseases, 35.9ms
# image 2/207 C:\juna27\PythonWork\AI\data\tomato_yolo\test\images\0a555f63-bf03-4958-8993-e1932b8dce9f___Crnl_L.Mold 9064.JPG: 416x416 1 healthy, 2 diseases, 37.9ms
# image 3/207 C:\juna27\PythonWork\AI\data\tomato_yolo\test\images\0a9b3ff4-5343-4814-ac2c-fdb3613d4e4d___Crnl_L.Mold 6559.JPG: 416x416 1 disease, 38.9ms
# image 4/207 C:\juna27\PythonWork\AI\data\tomato_yolo\test\images\0ac36661-a47d-47ff-8948-42edec033b87___Crnl_L.Mold 9127.JPG: 416x416 1 disease, 42.9ms
# image 5/207 C:\juna27\PythonWork\AI\data\tomato_yolo\test\images\0adab1d4-5696-4cd8-8453-3931b70e856d___Crnl_L.Mold 8689.JPG: 416x416 2 healthys, 46.9ms
# image 6/207 C:\juna27\PythonWork\AI\data\tomato_yolo\test\images\0ae36892-5cb1-476e-8a51-b7fd8183a535___Crnl_L.Mold 6728.JPG: 416x416 1 healthy, 1 disease, 41.9ms
# ...

# %% [markdown]
# ### best 6 + 2 추론 해보기

# %% [markdown]
# Ultralytics YOLOv8.0.121  Python-3.9.13 torch-2.0.1+cpu CPU
# yolo\engine\trainer: task=detect, mode=train, model=yolov8n.pt, data=C:/juna27/PythonWork/AI/data/tomato_yolo/tom_out.yaml,
#
# epochs=6, patience=20, batch=64, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, fraction=1.0, profile=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs\detect\train3
# Overriding model.yaml nc=80 with nc=2

# %% [markdown]
# ### train2 (lap)
#
# - v8 n

# %%
# import yaml

# data = {
#     "train" : "train/images/",
#     "val" : "val/images/",
# #     "test" : "tomato_yolo/test/images/",
#     "nc" : 2,
#     "names": ['healthy', 'disease']
# }

# with open("data/tomato_yolo/tom_out.yaml", "w") as f:
#     yaml.dump(data, f)

# %%
# model.train(data="C:/juna27/PythonWork/AI/data/tomato_yolo/tom_out.yaml",
#             epochs=4, patience=20,
#             batch=32, imgsz=416)

# %%
Ultralytics YOLOv8.0.121  Python-3.9.13 torch-2.0.1+cpu CPU
yolo\engine\trainer: task=detect, mode=train, model=yolov8n.pt, data=C:/juna27/PythonWork/AI/data/tomato_yolo/tom_out.yaml, epochs=4, patience=20, batch=32, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, fraction=1.0, profile=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs\detect\train2
Overriding model.yaml nc=80 with nc=2

                   from  n    params  module                                       arguments                     
  0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]                 
  1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]                
  2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]             
  3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]                
  4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]             
  5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]               
  6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]           
  7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]              
  8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]           
  9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]                 
 10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']          
 11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]                           
Start Training : 2023-06-25 04:19:47.373779
 12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]                 
 13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']          
 14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]                           
 15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]                  
 16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]                
 17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]                           
 18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]                 
 19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]              
 20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]                           
 21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]                 
 22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]           
Model summary: 225 layers, 3011238 parameters, 3011222 gradients

Transferred 319/355 items from pretrained weights
TensorBoard: Start with 'tensorboard --logdir runs\detect\train2', view at http://localhost:6006/
train: Scanning C:\juna27\PythonWork\AI\data\tomato_yolo\tr
val: Scanning C:\juna27\PythonWork\AI\data\tomato_yolo\val\
Plotting labels to runs\detect\train2\labels.jpg... 
optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
Image sizes 416 train, 416 val
Using 0 dataloader workers
Logging results to runs\detect\train2
Starting training for 4 epochs...

      Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
        1/4         0G     0.8042      1.259      1.157    
                 Class     Images  Instances      Box(P    
                   all       4669       4669      0.701      0.371      0.463      0.296

      Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
        2/4         0G     0.7785     0.8301      1.129    
                 Class     Images  Instances      Box(P    
                   all       4669       4669      0.657      0.472      0.475      0.352

      Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
        3/4         0G     0.7169     0.7151      1.097    
                 Class     Images  Instances      Box(P    
                   all       4669       4669      0.777      0.655      0.733      0.495

      Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
        4/4         0G     0.6548     0.6354      1.072    
                 Class     Images  Instances      Box(P    
                   all       4669       4669      0.836      0.615       0.74      0.537

4 epochs completed in 7.390 hours.
Optimizer stripped from runs\detect\train2\weights\last.pt, 6.2MB
Optimizer stripped from runs\detect\train2\weights\best.pt, 6.2MB

Validating runs\detect\train2\weights\best.pt...
Ultralytics YOLOv8.0.121  Python-3.9.13 torch-2.0.1+cpu CPU
Model summary (fused): 168 layers, 3006038 parameters, 0 gradients
                 Class     Images  Instances      Box(P    
                   all       4669       4669      0.836      0.614      0.739      0.537
               healthy       4669       4423      0.955      0.473      0.731      0.535
               disease       4669        246      0.718      0.756      0.748      0.539
Speed: 1.0ms preprocess, 62.2ms inference, 0.0ms loss, 0.6ms postprocess per image
Results saved to runs\detect\train2

# %% [markdown]
# ### train3 (lap)

# %%
  # "train" : "train/images/",
  #   "val" : "val/images/",
  #   "test" : "test/images/",
  #   "nc" : 2,
  #   "names": ['healthy', 'disease']

# %%
            # epochs=6, patience=20,
            # batch=64, imgsz=416)

# %%
New https://pypi.org/project/ultralytics/8.0.122 available  Update with 'pip install -U ultralytics'
Ultralytics YOLOv8.0.121  Python-3.9.13 torch-2.0.1+cpu CPU
yolo\engine\trainer: task=detect, mode=train, model=yolov8n.pt, data=C:/juna27/PythonWork/AI/data/tomato_yolo/tom_out.yaml, epochs=6, patience=20, batch=64, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, fraction=1.0, profile=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs\detect\train3
Overriding model.yaml nc=80 with nc=2

                   from  n    params  module                                       arguments                     
  0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]                 
  1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]                
Start Training : 2023-06-25 15:49:45.959404
  2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]             
  3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]                
  4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]             
  5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]               
  6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]           
  7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]              
  8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]           
  9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]                 
 10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']          
 11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]                           
 12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]                 
 13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']          
 14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]                           
 15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]                  
 16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]                
 17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]                           
 18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]                 
 19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]              
 20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]                           
 21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]                 
 22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]           
Model summary: 225 layers, 3011238 parameters, 3011222 gradients

Transferred 319/355 items from pretrained weights
TensorBoard: Start with 'tensorboard --logdir runs\detect\train3', view at http://localhost:6006/
train: Scanning C:\juna27\PythonWork\AI\data\tomato_yolo\tr
val: Scanning C:\juna27\PythonWork\AI\data\tomato_yolo\val\
Plotting labels to runs\detect\train3\labels.jpg... 
optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
Image sizes 416 train, 416 val
Using 0 dataloader workers
Logging results to runs\detect\train3
Starting training for 6 epochs...

      Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
        1/6         0G     0.7788      1.328      1.146    
                 Class     Images  Instances      Box(P    
                   all       4669       4669      0.453      0.476      0.433      0.287

      Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
        2/6         0G     0.7665     0.8459      1.119    
                 Class     Images  Instances      Box(P    
                   all       4669       4669      0.494      0.422      0.399      0.276

      Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
        3/6         0G     0.7529      0.762      1.114    
                 Class     Images  Instances      Box(P    
                   all       4669       4669      0.718      0.592      0.645      0.444

      Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
        4/6         0G     0.7132     0.6874      1.097    
                 Class     Images  Instances      Box(P    
                   all       4669       4669      0.817       0.53      0.636      0.451

      Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
        5/6         0G     0.6833     0.6591      1.085    
                 Class     Images  Instances      Box(P    
                   all       4669       4669      0.789      0.637      0.711      0.497

      Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
        6/6         0G     0.6264     0.5949      1.059    
                 Class     Images  Instances      Box(P    
                   all       4669       4669      0.792      0.703      0.787      0.561

6 epochs completed in 12.585 hours.
Optimizer stripped from runs\detect\train3\weights\last.pt, 6.2MB
Optimizer stripped from runs\detect\train3\weights\best.pt, 6.2MB

Validating runs\detect\train3\weights\best.pt...
Ultralytics YOLOv8.0.121  Python-3.9.13 torch-2.0.1+cpu CPU
Model summary (fused): 168 layers, 3006038 parameters, 0 gradients
                 Class     Images  Instances      Box(P    
                   all       4669       4669      0.792      0.702      0.787      0.561
               healthy       4669       4423      0.711      0.732      0.782      0.573
               disease       4669        246      0.873      0.673      0.792       0.55
Speed: 1.0ms preprocess, 60.8ms inference, 0.0ms loss, 0.6ms postprocess per image
Results saved to runs\detect\train3
End of Training : 2023-06-26 04:43:15.359642

Time taken : 12:53:29.400238

# %%
New https://pypi.org/project/ultralytics/8.0.123 available  Update with 'pip install -U ultralytics'
Ultralytics YOLOv8.0.117  Python-3.9.13 torch-2.0.1+cpu CPU
yolo\engine\trainer: task=detect, mode=train, model=C:/juna27/PythonWork/AI/data/tomato_yolo/best_epochs6.pt, data=C:/juna27/PythonWork/AI/data/tomato_yolo/tom_out.yaml, epochs=2, patience=20, batch=32, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, fraction=1.0, profile=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs\detect\train2

                   from  n    params  module                                       arguments                     
  0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]                 
  1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]                
  2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]             
  3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]                
  4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]             
  5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]               
  6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]           
  7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]              
  8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]           
  9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]                 
 10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']          
 11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]                           
 12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]                 
 13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']          
 14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]                           
 15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]                  
 16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]                
 17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]                           
 18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]                 
 19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]              
 20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]                           
 21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]                 
 22        [15, 18, 21]  1    751702  ultralytics.nn.modules.head.Detect           [2, [64, 128, 256]]           
Start Training : 2023-06-26 12:47:52.740834
Model summary: 225 layers, 3011238 parameters, 3011222 gradients, 8.2 GFLOPs

Transferred 355/355 items from pretrained weights
TensorBoard: Start with 'tensorboard --logdir runs\detect\train2', view at http://localhost:6006/
train: Scanning C:\juna27\PythonWork\AI\data\tomato_yolo\train\labels.cache... 15476 images, 0 backgrounds, 0 corrupt: 
val: Scanning C:\juna27\PythonWork\AI\data\tomato_yolo\val\labels.cache... 4669 images, 0 backgrounds, 0 corrupt: 100%|
Plotting labels to runs\detect\train2\labels.jpg... 
optimizer: AdamW(lr=0.001667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
Image sizes 416 train, 416 val
Using 0 dataloader workers
Logging results to runs\detect\train2
Starting training for 2 epochs...

      Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
        1/2         0G      0.608     0.5792      1.049         52        416: 100%|██████████| 484/484 [1:13:07<00:00,
                 Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 73/73 [14:41
                   all       4669       4669      0.847      0.572      0.692      0.502

      Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
        2/2         0G     0.6121     0.5795      1.051         48        416: 100%|██████████| 484/484 [1:06:45<00:00,
                 Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 73/73 [15:06
                   all       4669       4669      0.717        0.7      0.744       0.53

2 epochs completed in 2.831 hours.
Optimizer stripped from runs\detect\train2\weights\last.pt, 6.2MB
Optimizer stripped from runs\detect\train2\weights\best.pt, 6.2MB

Validating runs\detect\train2\weights\best.pt...
Ultralytics YOLOv8.0.117  Python-3.9.13 torch-2.0.1+cpu CPU
Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
                 Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 73/73 [13:07
                   all       4669       4669      0.715      0.701      0.744       0.53
               healthy       4669       4423      0.853      0.645      0.809      0.588
               disease       4669        246      0.577      0.756      0.679      0.472
Speed: 0.6ms preprocess, 30.3ms inference, 0.0ms loss, 0.4ms postprocess per image
Results saved to runs\detect\train2
End of Training : 2023-06-26 15:51:03.805797

Time taken : 3:03:11.064963

# %% [markdown]
# ## pc train3

# %%
import yaml

data = {
    "train" : "train/images/",
    "val" : "val/images/",
    "test" : "test/images/",
    "nc" : 3,
    "names": ['healthy', 'Leaf mold', 'TYLCV']
}

with open("data/tomato_yolo/tom_out_leaf.yaml", "w") as f:
    yaml.dump(data, f)

# %%
start_time = datetime.now()
print("Start Training :", start_time)
##########


model.train(data="C:/juna27/PythonWork/AI/data/tomato_yolo/tom_out_leaf.yaml",
            epochs=8, patience=4,
            batch=32, imgsz=416)


##########
end_time = datetime.now()
print("End of Training :", end_time)
print("\nTime taken :", end_time-start_time)
# Out:
# Start Training : 2023-06-27 18:58:06.633668
# New https://pypi.org/project/ultralytics/8.0.123 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.117  Python-3.9.13 torch-2.0.1+cpu CPU
# ...

# %%
Results saved to runs\detect\train3

# %%
C:\juna27\PythonWork\AI\runs\detect\train3

# %%
Start Training : 2023-06-27 18:58:06.633668
New https://pypi.org/project/ultralytics/8.0.123 available  Update with 'pip install -U ultralytics'
Ultralytics YOLOv8.0.117  Python-3.9.13 torch-2.0.1+cpu CPU
yolo\engine\trainer: task=detect, mode=train, model=yolov8n.pt, data=C:/juna27/PythonWork/AI/data/tomato_yolo/tom_out_leaf.yaml, epochs=8, patience=4, batch=32, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, fraction=1.0, profile=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs\detect\train3
Overriding model.yaml nc=80 with nc=3

                   from  n    params  module                                       arguments                     
  0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]                 
  1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]                
  2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]             
  3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]                
  4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]             
  5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]               
  6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]           
  7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]              
  8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]           
  9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]                 
 10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']          
 11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]                           
 12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]                 
 13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']          
 14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]                           
 15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]                  
 16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]                
 17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]                           
 18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]                 
 19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]              
 20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]                           
 21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]                 
 22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]           
Model summary: 225 layers, 3011433 parameters, 3011417 gradients, 8.2 GFLOPs

Transferred 319/355 items from pretrained weights
TensorBoard: Start with 'tensorboard --logdir runs\detect\train3', view at http://localhost:6006/
train: Scanning C:\juna27\PythonWork\AI\data\tomato_yolo\train\labels... 25446 images, 0 backgrounds, 0 corrupt: 100%|█
train: New cache created: C:\juna27\PythonWork\AI\data\tomato_yolo\train\labels.cache
val: Scanning C:\juna27\PythonWork\AI\data\tomato_yolo\val\labels... 4934 images, 0 backgrounds, 0 corrupt: 100%|██████
val: New cache created: C:\juna27\PythonWork\AI\data\tomato_yolo\val\labels.cache
Plotting labels to runs\detect\train3\labels.jpg... 
optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
Image sizes 416 train, 416 val
Using 0 dataloader workers
Logging results to runs\detect\train3
Starting training for 8 epochs...

      Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
        1/8         0G      1.004      1.475       1.25         16        416: 100%|██████████| 796/796 [1:56:32<00:00,
                 Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 78/78 [16:48
                   all       4934       4934      0.703      0.674      0.711       0.53

      Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
        2/8         0G     0.9901      1.034      1.225         15        416: 100%|██████████| 796/796 [1:55:14<00:00,
                 Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 78/78 [20:33
                   all       4934       4934      0.799      0.818      0.832      0.648

      Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
        3/8         0G     0.9549     0.9522      1.205         15        416: 100%|██████████| 796/796 [2:22:38<00:00,
                 Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 78/78 [17:04
                   all       4934       4934      0.837      0.826      0.846       0.67

      Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
        4/8         0G     0.9188     0.8912      1.186         13        416: 100%|██████████| 796/796 [2:09:34<00:00,
                 Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 78/78 [17:18
                   all       4934       4934      0.862      0.821      0.881      0.722

      Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
        5/8         0G     0.8915     0.8551      1.171         12        416: 100%|██████████| 796/796 [1:52:02<00:00,
                 Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 78/78 [17:11
                   all       4934       4934      0.858       0.83      0.877      0.721

      Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
        6/8         0G     0.8467      0.801      1.151         17        416: 100%|██████████| 796/796 [1:53:08<00:00,
                 Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 78/78 [17:17
                   all       4934       4934      0.885      0.856      0.899      0.746

      Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
        7/8         0G     0.8142     0.7527      1.138         17        416: 100%|██████████| 796/796 [1:55:50<00:00,
                 Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 78/78 [18:11
                   all       4934       4934      0.883      0.859      0.899      0.758

      Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
        8/8         0G     0.7722     0.7064      1.115         13        416: 100%|██████████| 796/796 [2:01:06<00:00,
                 Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 78/78 [17:32
                   all       4934       4934      0.881      0.873      0.907      0.762

8 epochs completed in 18.471 hours.
Optimizer stripped from runs\detect\train3\weights\last.pt, 6.2MB
Optimizer stripped from runs\detect\train3\weights\best.pt, 6.2MB

Validating runs\detect\train3\weights\best.pt...
Ultralytics YOLOv8.0.117  Python-3.9.13 torch-2.0.1+cpu CPU
Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
                 Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 78/78 [16:16
                   all       4934       4934      0.881      0.874      0.907      0.762
               healthy       4934       1888      0.996      0.987      0.995      0.972
             Leaf mold       4934       1210      0.855      0.867        0.9      0.684
                 TYLCV       4934       1836      0.791      0.768      0.825      0.629
Speed: 0.6ms preprocess, 29.9ms inference, 0.0ms loss, 0.4ms postprocess per image
Results saved to runs\detect\train3
End of Training : 2023-06-28 13:48:27.677741

Time taken : 18:50:21.044073
