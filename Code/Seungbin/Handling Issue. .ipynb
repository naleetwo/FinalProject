# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np

img_path="D:\\smartfarm_tomato\\data_for_yolo\\train\\image\\V001_tom1_00_061_e_14_20220101_27_05094434_40158887.png"

# Open the image file
image = cv2.imread(img_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Create figure and axes
fig, ax = plt.subplots(1)

# Display the image
ax.imshow(im)

# Here, bbox is a list of four values [x, y, width, height]
x, y, width, height = 0.5790123456790123, 0.476147762345679, 0.1790123456790124, 0.09292052469135802

# Convert to actual pixel values
img_width, img_height = 1080, 1920 

x *= img_width
y *= img_height
width *= img_width
height *= img_height

# Create a Rectangle patch
bbox = patches.Rectangle((x, y), width, height, linewidth=5, edgecolor='r')

# Add the patch to the Axes
ax.add_patch(bbox)

plt.show()

# %%
# ?patches.Rectangle

# %%
import cv2
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import json

# JSON 파일 경로
json_path = "D:\\smartfarm_tomato\\data_for_yolo\\train\\aa\\V001_tom1_00_061_e_14_20220101_27_05094434_40158887.json"

# JSON 파일 열기 및 데이터 로드
with open(json_path, "r") as f:
    data = json.load(f)

# 이미지 읽기
image_path = 'D:\\smartfarm_tomato\\data_for_yolo\\train\\image\\V001_tom1_00_061_e_14_20220101_27_05094434_40158887.png'  
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# 도형들을 그릴 figure와 axes 생성
fig, ax = plt.subplots(1)

# 이미지 표시
ax.imshow(image)

# 각 도형에 대하여
for shape in data["shapes"]:
    # 점들의 좌표를 불러옵니다
    points = shape["points"]

    # 점의 개수를 확인하고, 점이 없는 경우는 무시합니다
    if len(points) == 0:
        continue

    print(points)  # <-- 좌표 출력

    # 폴리곤 생성 (여기서는 x, y 좌표가 분리되어 입력되어야 하므로 zip(*points)를 사용합니다)
    polygon = patches.Polygon(points, fill=False, edgecolor='red')

    # axes에 폴리곤 추가
    ax.add_patch(polygon)

plt.show()
# Out:
# [[586.9090909090909, 828.9966329966329], [566.03367003367, 843.4747474747475], [547.5151515151515, 859.973063973064], [532.026936026936, 889.2659932659932], [528.6666666666666, 918.0], [536.0673400673401, 951.8922558922558], [552.0, 974.0], [561.3333333333334, 980.0], [581.0, 990.0], [596.6734006734006, 996.6734006734006], [627.6498316498316, 1003.4074074074074], [650.8821548821549, 1000.7138047138046], [681.0, 988.0], [697.0, 973.0], [708.0, 956.0], [722.0, 922.0], [715.0, 892.0], [702.0, 871.0], [643.0, 829.0], [619.0, 825.0]]
# [[706.0, 738.0], [686.0, 738.8888888888889], [661.6666666666666, 750.6818181818181], [634.0, 774.6666666666666], [626.6666666666666, 786.0], [617.6666666666665, 811.7179487179487], [617.6666666666665, 824.5384615384615], [643.3333333333334, 828.2222222222222], [702.4444444444445, 871.3333333333334], [715.7777777777778, 894.0], [721.5555555555555, 923.3333333333334], [707.7777777777778, 959.7777777777778], [765.8333333333333, 960.9090909090909], [799.9242424242424, 949.5454545454545], [835.6153846153845, 921.9743589743589], [848.6666666666666, 889.5555555555555], [850.0, 858.4444444444445], [843.1060606060605, 831.3636363636364], [821.8939393939394, 805.6060606060606], [800.6818181818181, 788.9393939393939], [785.530303030303, 780.2272727272726], [774.0769230769231, 768.1282051282051], [747.2463768115941, 749.4202898550724]]

# %%
import json

# JSON 파일 경로
json_path = "D:\\smartfarm_tomato\\data_for_yolo\\train\\aa\\V001_tom1_00_061_e_14_20220101_27_05094434_40158887.json"

# JSON 파일 열기 및 데이터 로드
with open(json_path, "r") as f:
    data = json.load(f)

# 도형들의 정보 출력
for i, shape in enumerate(data["shapes"]):
    print(f"Shape {i + 1}:")
    print(f"  Label: {shape['label']}")
    print(f"  Points: {shape['points']}")
    print(f"  Shape type: {shape['shape_type']}\n")
# Out:
# Shape 1:
#   Label: tom_fruit_breaker_poly
#   Points: [[586.9090909090909, 828.9966329966329], [566.03367003367, 843.4747474747475], [547.5151515151515, 859.973063973064], [532.026936026936, 889.2659932659932], [528.6666666666666, 918.0], [536.0673400673401, 951.8922558922558], [552.0, 974.0], [561.3333333333334, 980.0], [581.0, 990.0], [596.6734006734006, 996.6734006734006], [627.6498316498316, 1003.4074074074074], [650.8821548821549, 1000.7138047138046], [681.0, 988.0], [697.0, 973.0], [708.0, 956.0], [722.0, 922.0], [715.0, 892.0], [702.0, 871.0], [643.0, 829.0], [619.0, 825.0]]
#   Shape type: polygon
#
# Shape 2:
#   Label: tom_fruit_breaker_poly
#   Points: [[706.0, 738.0], [686.0, 738.8888888888889], [661.6666666666666, 750.6818181818181], [634.0, 774.6666666666666], [626.6666666666666, 786.0], [617.6666666666665, 811.7179487179487], [617.6666666666665, 824.5384615384615], [643.3333333333334, 828.2222222222222], [702.4444444444445, 871.3333333333334], [715.7777777777778, 894.0], [721.5555555555555, 923.3333333333334], [707.7777777777778, 959.7777777777778], [765.8333333333333, 960.9090909090909], [799.9242424242424, 949.5454545454545], [835.6153846153845, 921.9743589743589], [848.6666666666666, 889.5555555555555], [850.0, 858.4444444444445], [843.1060606060605, 831.3636363636364], [821.8939393939394, 805.6060606060606], [800.6818181818181, 788.9393939393939], [785.530303030303, 780.2272727272726], [774.0769230769231, 768.1282051282051], [747.2463768115941, 749.4202898550724]]
#   Shape type: polygon

# %%
print(data.keys())
print(data["shapes"])
print("---")
point=data["shapes"][0]["points"]
print(min(point))
# Out:
# dict_keys(['version', 'flags', 'shapes', 'imagePath', 'imageData', 'imageHeight', 'imageWidth', 'file_attributes', 'growth_indicators'])
# [{'label': 'tom_fruit_breaker_poly', 'points': [[586.9090909090909, 828.9966329966329], [566.03367003367, 843.4747474747475], [547.5151515151515, 859.973063973064], [532.026936026936, 889.2659932659932], [528.6666666666666, 918.0], [536.0673400673401, 951.8922558922558], [552.0, 974.0], [561.3333333333334, 980.0], [581.0, 990.0], [596.6734006734006, 996.6734006734006], [627.6498316498316, 1003.4074074074074], [650.8821548821549, 1000.7138047138046], [681.0, 988.0], [697.0, 973.0], [708.0, 956.0], [722.0, 922.0], [715.0, 892.0], [702.0, 871.0], [643.0, 829.0], [619.0, 825.0]], 'group_id': None, 'shape_type': 'polygon', 'flags': {}}, {'label': 'tom_fruit_breaker_poly', 'points': [[706.0, 738.0], [686.0, 738.8888888888889], [661.6666666666666, 750.6818181818181], [634.0, 774.6666666666666], [626.6666666666666, 786.0], [617.6666666666665, 811.7179487179487], [617.6666666666665, 824.5384615384615], [643.3333333333334, 828.2222222222222], [702.4444444444445, 871.3333333333334], [715.7777777777778, 894.0], [721.5555555555555, 923.3333333333334], [707.7777777777778, 959.7777777777778], [765.8333333333333, 960.9090909090909], [799.9242424242424, 949.5454545454545], [835.6153846153845, 921.9743589743589], [848.6666666666666, 889.5555555555555], [850.0, 858.4444444444445], [843.1060606060605, 831.3636363636364], [821.8939393939394, 805.6060606060606], [800.6818181818181, 788.9393939393939], [785.530303030303, 780.2272727272726], [774.0769230769231, 768.1282051282051], [747.2463768115941, 749.4202898550724]], 'group_id': None, 'shape_type': 'polygon', 'flags': {}}]
# ---
# [528.6666666666666, 918.0]

# %%
for shape in data["shapes"]:
    xs = [point[0] for point in shape["points"]]
    ys = [point[1] for point in shape["points"]]
    x1 = min(xs)
    y1 = min(ys)
    x2 = max(xs)
    y2 = max(ys)
    x_center = (x1 + x2) / 2.0 / data['imageWidth']
    y_center = (y1 + y2) / 2.0 / data['imageHeight']
    width = abs(x2 - x1) / data['imageWidth']
    height = abs(y2 - y1) / data['imageHeight']
    
    print(x_center,y_center,width,height)   
    
print("---"*20)

for shape in data["shapes"]:
    xs = [point[0] for point in shape["points"]]
    ys = [point[1] for point in shape["points"]]
    x1 = min(xs)
    y1 = min(ys)
    x2 = max(xs)
    y2 = max(ys)
    x_center = (x1 + x2) / 2.0 
    y_center = (y1 + y2) / 2.0 
    width = abs(x2 - x1)
    height = abs(y2 - y1)
    
    print(x_center,y_center,width,height)
# Out:
# 0.5790123456790123 0.476147762345679 0.1790123456790124 0.09292052469135802
# 0.6794753086419753 0.44242424242424244 0.2151234567901236 0.11609848484848483
# ------------------------------------------------------------
# 625.3333333333333 914.2037037037037 193.33333333333337 178.4074074074074
# 733.8333333333333 849.4545454545455 232.33333333333348 222.90909090909088

# %%
## x_max, x_min 구하기
print(data.keys())
points=data["shapes"][0]["points"]
print(points)
print("---"*20)
print([sublist[0] for sublist in points])
# Out:
# dict_keys(['version', 'flags', 'shapes', 'imagePath', 'imageData', 'imageHeight', 'imageWidth', 'file_attributes', 'growth_indicators'])
# [[586.9090909090909, 828.9966329966329], [566.03367003367, 843.4747474747475], [547.5151515151515, 859.973063973064], [532.026936026936, 889.2659932659932], [528.6666666666666, 918.0], [536.0673400673401, 951.8922558922558], [552.0, 974.0], [561.3333333333334, 980.0], [581.0, 990.0], [596.6734006734006, 996.6734006734006], [627.6498316498316, 1003.4074074074074], [650.8821548821549, 1000.7138047138046], [681.0, 988.0], [697.0, 973.0], [708.0, 956.0], [722.0, 922.0], [715.0, 892.0], [702.0, 871.0], [643.0, 829.0], [619.0, 825.0]]
# ------------------------------------------------------------
# [586.9090909090909, 566.03367003367, 547.5151515151515, 532.026936026936, 528.6666666666666, 536.0673400673401, 552.0, 561.3333333333334, 581.0, 596.6734006734006, 627.6498316498316, 650.8821548821549, 681.0, 697.0, 708.0, 722.0, 715.0, 702.0, 643.0, 619.0]

# %%
import cv2

img_path="D:\\smartfarm_tomato\\data_for_yolo\\train\\image\\V001_tom1_00_061_e_14_20220101_27_05094434_40158887.png"

# Open the image file
image = cv2.imread(img_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Create figure and axes
fig, ax = plt.subplots(1)

# Display the image
ax.imshow(image)

# Here, bbox is a list of four values [x, y, width, height]
# x, y, width, height = 0.5790123456790123, 0.476147762345679, 0.1790123456790124, 0.09292052469135802
points=data["shapes"][1]["points"]

x_max=max([sublist[0] for sublist in points])
x_min=min([sublist[0] for sublist in points])
y_max=max([sublist[1] for sublist in points])
y_min=min([sublist[1] for sublist in points])

x,y=(x_max+x_min)/2,(y_max+y_min)/2
width=(x_max-x_min)
hegiht=(y_max-y_min)

center_x, center_y = (x_max + x_min) / 2, (y_max + y_min) / 2
ax.scatter(center_x, center_y, color='r')

# Create a Rectangle patch
bbox = patches.Rectangle((x, y), width, height, linewidth=2, edgecolor='r', facecolor=None)

# Add the patch to the Axes
ax.add_patch(bbox)

plt.show()

# %%
# ?patches.Rectangle

# %%
img_path="C:\\csb13\\ai\\content\\Aquarium Combined.v2-raw-1024.yolov8\\test\\images\\IMG_2289_jpeg_jpg.rf.fe2a7a149e7b11f2313f5a7b30386e85.jpg"

# Open the image file
image = cv2.imread(img_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Create figure and axes
fig, ax = plt.subplots(1)

# Display the image
ax.imshow(image)

# Here, bbox is a list of four values [x, y, width, height]
x, y, width, height = 0.4453125, 0.5888671875, 0.5104166666666666, 0.236328125



# Convert to actual pixel values
img_width, img_height = 768, 1024 

x *= img_width
y *= img_height
width *= img_width
height *= img_height

plt.scatter(x, y, color='red', s=5)

# Create a Rectangle patch
bbox = patches.Rectangle((x, y), width, height, linewidth=5, edgecolor='r')

# Add the patch to the Axes
ax.add_patch(bbox)

plt.show()

# %%
# ?plt.scatter

# %%
# Dictionary mapping type to class id
type_to_id = { 'd1': 2, 'd2': 2, 'f': 3, 'e': 4}

# Input directories and output directory
input_dirs = ['d1.꽃(개화군)', 'd2.꽃(착과군)', 'e.열매', 'f.만개꽃']
output_dir = 'D:\\097.지능형 스마트팜 통합 데이터(토마토)\\01.데이터\\text'
base_dir = 'D:\\097.지능형 스마트팜 통합 데이터(토마토)\\01.데이터\\1.Training\\라벨링데이터'

# Function to convert polygon to bounding box
def poly_to_bbox(poly_points):
    xs = [point[0] for point in poly_points]
    ys = [point[1] for point in poly_points]
    
    x1 = min(xs)
    y1 = min(ys)
    x2 = max(xs)
    y2 = max(ys)
    
    return [[x1, y1], [x2, y2]]

# Loop over input directories
for input_dir in tqdm(input_dirs, desc="Processing directories"):
    for filename in os.listdir(os.path.join(base_dir, input_dir)):
        if filename.endswith('.json'):
            # Open JSON file
            with open(os.path.join(base_dir, input_dir, filename)) as f:
                data = json.load(f)
                
                # Create directory if not exists
                os.makedirs(os.path.join(output_dir, input_dir), exist_ok=True)

                # Create output .txt file
                with open(os.path.join(output_dir, input_dir, os.path.splitext(filename)[0] + '.txt'), 'w') as outfile:
                    # Loop over shapes in data
                    for shape in data['shapes']:
                        # Get class id from type
                        class_id = type_to_id[data['file_attributes']["type"]]
                        
                        # Convert polygon to bounding box
                        [x1, y1], [x2, y2] = poly_to_bbox(shape['points'])

                        # Calculate YOLO format values
                        x_center = (x1 + x2) / 2.0 / data['imageWidth']
                        y_center = (y1 + y2) / 2.0 / data['imageHeight']
                        width = abs(x2 - x1) / data['imageWidth']
                        height = abs(y2 - y1) / data['imageHeight']

                        # Write to output file
                        outfile.write(f'{class_id} {x_center} {y_center} {width} {height}\n')
